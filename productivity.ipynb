# %%
import pandas as  pd

# %%
df=pd.read_csv("productivity_tracker_dataset.csv")

# %%
df.head()
# Out:
#    UserID     Name  Age Occupation  Week  StudyHours  WorkHours  \
# 0       1  William   39   Engineer     1         5.0       34.8
# 1       1  William   39   Engineer     2        10.3       29.6
# 2       1  William   39   Engineer     3        10.0       26.1
# 3       1  William   39   Engineer     4         8.2       42.5
# 4       1  William   39   Engineer     5        10.8       34.8
#
#    ExerciseHours  ScreenTimeHours  ProductivityScore
# 0            4.2             44.6               10.9
# 1            4.6             41.6                9.6
# 2            3.5             35.9               10.0
# 3            4.8             47.0               14.1
# 4            4.1             37.5               13.7

# %%
df.drop(columns=['UserID','Name','Occupation','Week','StudyHours'],inplace=True)

# %%
df
# Out:
#       Age  WorkHours  ExerciseHours  ScreenTimeHours  ProductivityScore
# 0      39       34.8            4.2             44.6               10.9
# 1      39       29.6            4.6             41.6                9.6
# 2      39       26.1            3.5             35.9               10.0
# 3      39       42.5            4.8             47.0               14.1
# 4      39       34.8            4.1             37.5               13.7
# ...   ...        ...            ...              ...                ...
# 1795   37       25.3            3.3             47.3               10.6
# 1796   37       32.7            3.1             35.3               11.4
# 1797   37       31.1            2.9             33.3               12.9
# 1798   37       31.2            3.5             36.9               11.9
# 1799   37       33.9            3.5             26.1               13.4
#
# [1800 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# Age                  0
# WorkHours            0
# ExerciseHours        0
# ScreenTimeHours      0
# ProductivityScore    0
# dtype: int64

# %%
df.corr()
# Out:
#                         Age  WorkHours  ExerciseHours  ScreenTimeHours  \
# Age                1.000000   0.031030       0.020151         0.027434
# WorkHours          0.031030   1.000000       0.007676        -0.027474
# ExerciseHours      0.020151   0.007676       1.000000        -0.014759
# ScreenTimeHours    0.027434  -0.027474      -0.014759         1.000000
# ProductivityScore -0.017837   0.594348       0.084710        -0.390507
#
#                    ProductivityScore
# Age                        -0.017837
# WorkHours                   0.594348
# ExerciseHours               0.084710
# ScreenTimeHours            -0.390507
# ProductivityScore           1.000000

# %%
ff=pd.read_csv("Time Management and Productivity Insights.csv")

# %%
ff
# Out:
#     User ID  Age  Daily Work Hours  Daily Leisure Hours  \
# 0         1   62               5.5                  4.0
# 1         2   32               4.8                  3.5
# 2         3   52               3.4                  2.1
# 3         4   50               9.4                  4.0
# 4         5   63               8.7                  5.6
# ..      ...  ...               ...                  ...
# 80       81   61               8.1                  3.4
# 81       82   29               7.0                  6.0
# 82       83   40               9.3                  4.1
# 83       84   27               6.1                  4.8
# 84       85   53               8.4                  2.9
#
#     Daily Exercise Minutes  Daily Sleep Hours  Productivity Score  \
# 0                       92                5.2                  55
# 1                        6                8.8                  69
# 2                       75                7.2                  68
# ...

# %%
ff.drop(columns=['User ID',	'Age','Daily Leisure Hours'	,'Commute Time (hours)'],inplace=True)

# %%
ff
# Out:
#     Daily Work Hours  Daily Exercise Minutes  Daily Sleep Hours  \
# 0                5.5                      92                5.2
# 1                4.8                       6                8.8
# 2                3.4                      75                7.2
# 3                9.4                      53                6.9
# 4                8.7                      46                7.4
# ..               ...                     ...                ...
# 80               8.1                      85                7.6
# 81               7.0                      55                7.4
# 82               9.3                      65                7.2
# 83               6.1                      90                6.8
# 84               8.4                      75                7.9
#
#     Productivity Score  Screen Time (hours)
# 0                   55                  3.7
# 1                   69                  7.2
# 2                   68                  3.3
# ...

# %%
ff.isnull().sum()
# Out:
# Daily Work Hours          0
# Daily Exercise Minutes    0
# Daily Sleep Hours         0
# Productivity Score        0
# Screen Time (hours)       0
# dtype: int64

# %%
ff.corr()
# Out:
#                         Daily Work Hours  Daily Exercise Minutes  \
# Daily Work Hours                1.000000                0.005266
# Daily Exercise Minutes          0.005266                1.000000
# Daily Sleep Hours               0.069106                0.077069
# Productivity Score              0.633503                0.207009
# Screen Time (hours)             0.419681                0.263492
#
#                         Daily Sleep Hours  Productivity Score  \
# Daily Work Hours                 0.069106            0.633503
# Daily Exercise Minutes           0.077069            0.207009
# Daily Sleep Hours                1.000000            0.166935
# Productivity Score               0.166935            1.000000
# Screen Time (hours)              0.221780            0.447820
#
#                         Screen Time (hours)
# Daily Work Hours                   0.419681
# Daily Exercise Minutes             0.263492
# Daily Sleep Hours                  0.221780
# ...

# %%
from sklearn.linear_model import LinearRegression 
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
x=ff[['Daily Work Hours',	'Daily Exercise Minutes'	,'Daily Sleep Hours','Screen Time (hours)']]
y=ff['Productivity Score']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(x_train)
X_test_scaled = scaler.transform(x_test)

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
r2_score(y_test,y_pred)
mean_squared_error(y_test,y_pred)
mean_absolute_error(y_test,y_pred)
# Out:
# 6.638602982254811

# %%
ff
# Out:
#     Daily Work Hours  Daily Exercise Minutes  Daily Sleep Hours  \
# 0                5.5                      92                5.2
# 1                4.8                       6                8.8
# 2                3.4                      75                7.2
# 3                9.4                      53                6.9
# 4                8.7                      46                7.4
# ..               ...                     ...                ...
# 80               8.1                      85                7.6
# 81               7.0                      55                7.4
# 82               9.3                      65                7.2
# 83               6.1                      90                6.8
# 84               8.4                      75                7.9
#
#     Productivity Score  Screen Time (hours)
# 0                   55                  3.7
# 1                   69                  7.2
# 2                   68                  3.3
# ...

# %%
ff['Productivity Score'].mean()
# Out:
# np.float64(82.17647058823529)

# %%
a=float(input("enter daily work in hours  "))
b=float(input("enter daily exercise in mintues   "))
c=float(input(" enter sleep  hours "))
d=float(input("enter screen time   in hours"))
prediction=model.predict([[a,b,c,d]])
print(f"predction of productivity score is : {prediction[0]:.2f}")
# Out:
# enter daily work in hours   8
# enter daily exercise in mintues    60
#  enter sleep  hours  7
# enter screen time   in hours 7
# predction of productivity score is : 86.63
# C:\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import joblib

# suppose your model variable is "model"
joblib.dump(model, "productivity_model.joblib")
# Out:
# ['productivity_model.joblib']
